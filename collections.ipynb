# %% [markdown]
# <a href="https://colab.research.google.com/github/nipundavid/3DOnWeb/blob/master/collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Structures (Built-in Collections)
#
# These store and organize data.
#
# | Type | Concept |
# |-----|--------|
# | List | Ordered mutable collection |
# | Tuple | Ordered immutable collection |
# | Dictionary | Key–value mapping |
#
# These belong to:
#
# **Python Built-in Data Structures / Collections**
#
# Example:
#
# ```python
# numbers = [1,2,3]        # list
# point = (10,20)          # tuple
# person = {"name":"Nipun"} # dictionary

# %%
# Given a list of number, return only even numbers
# I/P [1,2,3,4,5,6] -> O/P [2,4,6]

numbers = [1,2,3,4,5,6]
result = list(filter(lambda x:x%2==0,numbers))
print(result)
# Out:
# [2, 4, 6]
